# %%
from iex import Stock

# %%
impo

# %%
goog = Stock("goog")
goog.chart_table(range='1d')
# Out:
# https://api.iextrading.com/1.0/stock/GOOG/chart/1d
#       average  changeOverTime     close      date      high     label  \
# 0    1178.844        0.000000  1177.780  20180914  1179.830  09:30 AM
# 1      -1.000             NaN       NaN  20180914    -1.000  09:31 AM
# 2      -1.000             NaN       NaN  20180914    -1.000  09:32 AM
# 3    1174.900       -0.003346  1174.900  20180914  1174.900  09:33 AM
# 4    1174.340       -0.003821  1174.340  20180914  1174.340  09:34 AM
# 5    1176.155       -0.002281  1176.150  20180914  1176.910  09:35 AM
# 6    1174.696       -0.003519  1174.405  20180914  1175.085  09:36 AM
# 7    1175.330       -0.002981  1175.190  20180914  1175.470  09:37 AM
# 8    1175.450       -0.002879  1175.450  20180914  1175.450  09:38 AM
# 9    1174.130       -0.003999  1174.130  20180914  1174.130  09:39 AM
# 10   1174.760       -0.003464  1174.760  20180914  1174.760  09:40 AM
# 11     -1.000             NaN       NaN  20180914    -1.000  09:41 AM
# ...

# %%
goog.company()
# Out:
# https://api.iextrading.com/1.0/stock/GOOG/company
# {'symbol': 'GOOG',
#  'companyName': 'Alphabet Inc.',
#  'exchange': 'Nasdaq Global Select',
#  'industry': 'Online Media',
#  'website': 'https://www.abc.xyz',
#  'description': 'Alphabet Inc is a provider of internet content products and portals. Its suite of brands includes Search, Android, YouTube, Apps, Maps & Ads.',
#  'CEO': 'Larry Page',
#  'issueType': 'cs',
#  'sector': 'Technology',
#  'tags': ['Technology', 'Internet Content & Information', 'Online Media']}

# %%
goog.effective_spread_table()
# Out:
# https://api.iextrading.com/1.0/stock/GOOG/effective-spread
#     effectiveQuoted  effectiveSpread  priceImprovement venue      venueName  \
# 0          0.939519         0.554163          0.020370  XCIS  NYSE National
# 1          0.765913         0.495163          0.087541  XCHI            CHX
# 2          0.749007         0.438109          0.100708  XPHL     Nasdaq PSX
# 3          0.849502         0.402805          0.048421  XASE  NYSE American
# 4          0.763732         0.377570          0.092370  XNYS           NYSE
# 5          0.719675         0.370235          0.112736  ARCX      NYSE Arca
# 6          0.715394         0.358942          0.110430  XBOS      Nasdaq BX
# 7          0.642131         0.357196          0.130285  XNGS         Nasdaq
# 8          0.585140         0.346270          0.160747  BATS       Cboe BZX
# 9          0.618597         0.344129          0.139189  BATY       Cboe BYX
# 10         0.649597         0.334304          0.134437  EDGX      Cboe EDGX
# ...

# %%
goog.earnings()
# Out:
# https://api.iextrading.com/1.0/stock/GOOG/earnings
# {'symbol': 'GOOG',
#  'earnings': [{'actualEPS': 11.75,
#    'consensusEPS': None,
#    'estimatedEPS': None,
#    'announceTime': 'AMC',
#    'numberOfEstimates': None,
#    'EPSSurpriseDollar': None,
#    'EPSReportDate': '2018-07-23',
#    'fiscalPeriod': 'Q2 2018',
#    'fiscalEndDate': '2018-06-30',
#    'yearAgo': 5.01,
#    'yearAgoChangePercent': 1.345309381237525,
#    'estimatedChangePercent': None,
#    'symbolId': 10656},
#   {'actualEPS': 9.93,
#    'consensusEPS': None,
#    'estimatedEPS': None,
#    'announceTime': 'AMC',
#    'numberOfEstimates': None,
#    'EPSSurpriseDollar': None,
#    'EPSReportDate': '2018-04-23',
#    'fiscalPeriod': 'Q1 2018',
#    'fiscalEndDate': '2018-03-31',
#    'yearAgo': 7.73,
#    'yearAgoChangePercent': 0.2846054333764553,
#    'estimatedChangePercent': None,
#    'symbolId': 10656},
#   {'actualEPS': 9.7,
#    'consensusEPS': None,
#    'estimatedEPS': None,
# ...

# %%
goog.financials()
# Out:
# https://api.iextrading.com/1.0/stock/GOOG/financials
# [{'reportDate': '2018-06-30',
#   'grossProfit': 18774000000,
#   'costOfRevenue': 13883000000,
#   'operatingRevenue': 32512000000,
#   'totalRevenue': 32657000000,
#   'operatingIncome': 7878000000,
#   'netIncome': 3195000000,
#   'researchAndDevelopment': 5114000000,
#   'operatingExpense': 10896000000,
#   'currentAssets': 124157000000,
#   'totalAssets': 211610000000,
#   'totalLiabilities': None,
#   'currentCash': 14148000000,
#   'currentDebt': None,
#   'totalCash': 102254000000,
#   'totalDebt': None,
#   'shareholderEquity': 162000000000,
#   'cashChange': 1821000000,
#   'cashFlow': 10132000000,
#   'operatingGainsLosses': -1068000000},
#  {'reportDate': '2018-03-31',
#   'grossProfit': 17679000000,
#   'costOfRevenue': 13467000000,
#   'operatingRevenue': 30996000000,
#   'totalRevenue': 31146000000,
#   'operatingIncome': 7001000000,
#   'netIncome': 9401000000,
#   'researchAndDevelopment': 5039000000,
# ...

# %%
goog.ohlc()
# Out:
# https://api.iextrading.com/1.0/stock/GOOG/ohlc
# {'open': {'price': 1159.98, 'time': 1536327000351},
#  'close': {'price': 1164.83, 'time': 1536350400554},
#  'high': 1175.26,
#  'low': 1157.215}

# %%
goog.book()
# Out:
# https://api.iextrading.com/1.0/stock/GOOG/book
# {'quote': {'symbol': 'GOOG',
#   'companyName': 'Alphabet Inc.',
#   'primaryExchange': 'Nasdaq Global Select',
#   'sector': 'Technology',
#   'calculationPrice': 'close',
#   'open': 1159.98,
#   'openTime': 1536327000351,
#   'close': 1164.83,
#   'closeTime': 1536350400554,
#   'high': 1175.26,
#   'low': 1157.215,
#   'latestPrice': 1164.83,
#   'latestSource': 'Close',
#   'latestTime': 'September 7, 2018',
#   'latestUpdate': 1536350400554,
#   'latestVolume': 1400943,
#   'iexRealtimePrice': None,
#   'iexRealtimeSize': None,
#   'iexLastUpdated': None,
#   'delayedPrice': 1164.83,
#   'delayedPriceTime': 1536350400554,
#   'extendedPrice': 1164.83,
#   'extendedChange': 0,
#   'extendedChangePercent': 0,
#   'extendedPriceTime': 1536353864525,
#   'previousClose': 1171.44,
#   'change': -6.61,
#   'changePercent': -0.00564,
#   'iexMarketPercent': None,
#   'iexVolume': None,
#   'avgTotalVolume': 1387593,
# ...

# %%
goog.quote()
# Out:
# https://api.iextrading.com/1.0/stock/GOOG/quote?displayPercent=false
# {'symbol': 'GOOG',
#  'companyName': 'Alphabet Inc.',
#  'primaryExchange': 'Nasdaq Global Select',
#  'sector': 'Technology',
#  'calculationPrice': 'close',
#  'open': 1159.98,
#  'openTime': 1536327000351,
#  'close': 1164.83,
#  'closeTime': 1536350400554,
#  'high': 1175.26,
#  'low': 1157.215,
#  'latestPrice': 1164.83,
#  'latestSource': 'Close',
#  'latestTime': 'September 7, 2018',
#  'latestUpdate': 1536350400554,
#  'latestVolume': 1400943,
#  'iexRealtimePrice': None,
#  'iexRealtimeSize': None,
#  'iexLastUpdated': None,
#  'delayedPrice': 1164.83,
#  'delayedPriceTime': 1536350400554,
#  'extendedPrice': 1164.83,
#  'extendedChange': 0,
#  'extendedChangePercent': 0,
#  'extendedPriceTime': 1536353864525,
#  'previousClose': 1171.44,
#  'change': -6.61,
#  'changePercent': -0.00564,
#  'iexMarketPercent': None,
#  'iexVolume': None,
#  'avgTotalVolume': 1387593,
#  'iexBidPrice': None,
# ...
